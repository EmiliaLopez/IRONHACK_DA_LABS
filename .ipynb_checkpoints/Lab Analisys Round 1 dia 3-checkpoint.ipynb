# %%
#Read the three files into python as dataframes

import pandas as pd

# %%
file1=pd.read_csv('file1.csv')
file2=pd.read_csv('file2.csv')
file3=pd.read_csv('file3.csv')

# %%
#Show the DataFrame's shape.
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
#Reviso data frames para comparar nombres de columnas
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
file3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
#Rearrange the columns in the dataframe file1 as needed 
file1.columns = ['Customer', 'State', 'Gender', 'Education', 'Customer_lifetime_value', 'Income', 'Monthly_premiun_auto', 'Number_of_open_complaints', 'Policy type', 'Vehicle_class', 'Total_claim_amount']

# %%
file1
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer_lifetime_value   Income  Monthly_premiun_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2.columns=file1.columns #las encimo
file3.columns=file1.columns

# %%
file2
# Out:
#     Customer       State Gender Education Customer_lifetime_value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly_premiun_auto Number_of_open_complaints  Policy type  \
# ...

# %%
file3
# Out:
#      Customer       State        Gender             Education  \
# 0     SA25987  Washington   3479.137523  High School or Below
# 1     TB86706     Arizona   2502.637401                Master
# 2     ZL73902      Nevada   3265.156348              Bachelor
# 3     KX23516  California   4455.843406  High School or Below
# 4     FN77294  California   7704.958480  High School or Below
# ...       ...         ...           ...                   ...
# 7065  LA72316  California  23405.987980              Bachelor
# 7066  PK87824  California   3096.511217               College
# 7067  TD14365  California   8163.890428              Bachelor
# 7068  UP19263  California   7524.442436               College
# 7069  Y167826  California   2611.836866               College
#
#      Customer_lifetime_value  Income  Monthly_premiun_auto  \
# 0                          M       0                   104
# 1                          M       0                    66
# ...

# %%
#Concatenate the three dataframes
df1=pd.concat([file1,file2,file3] ,axis=0)

# %%
df1
# Out:
#      Customer       State       Gender             Education  \
# 0     RB50392  Washington          NaN                Master
# 1     QZ44356     Arizona            F              Bachelor
# 2     AI49188      Nevada            F              Bachelor
# 3     WW63253  California            M              Bachelor
# 4     GA49547  Washington            M  High School or Below
# ...       ...         ...          ...                   ...
# 7065  LA72316  California  23405.98798              Bachelor
# 7066  PK87824  California  3096.511217               College
# 7067  TD14365  California  8163.890428              Bachelor
# 7068  UP19263  California  7524.442436               College
# 7069  Y167826  California  2611.836866               College
#
#      Customer_lifetime_value   Income  Monthly_premiun_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# ...

# %%
df1.columns = ['Customer', 'State', 'Gender', 'Education', 'Customer lifetime value', 'Income', 'Monthly premiun auto', 'Number of open complaints', 'Policy type', 'Vehicle class', 'Total claim amount']
df1
# Out:
#      Customer       State       Gender             Education  \
# 0     RB50392  Washington          NaN                Master
# 1     QZ44356     Arizona            F              Bachelor
# 2     AI49188      Nevada            F              Bachelor
# 3     WW63253  California            M              Bachelor
# 4     GA49547  Washington            M  High School or Below
# ...       ...         ...          ...                   ...
# 7065  LA72316  California  23405.98798              Bachelor
# 7066  PK87824  California  3096.511217               College
# 7067  TD14365  California  8163.890428              Bachelor
# 7068  UP19263  California  7524.442436               College
# 7069  Y167826  California  2611.836866               College
#
#      Customer lifetime value   Income  Monthly premiun auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# ...

# %%
df1 = df1.reset_index(drop=True) #hay solo 7069 registros en el indice para resetearlo usamos la sintasis: dataframe.reset_index( drop=true)
df1
# Out:
#       Customer       State       Gender             Education  \
# 0      RB50392  Washington          NaN                Master
# 1      QZ44356     Arizona            F              Bachelor
# 2      AI49188      Nevada            F              Bachelor
# 3      WW63253  California            M              Bachelor
# 4      GA49547  Washington            M  High School or Below
# ...        ...         ...          ...                   ...
# 12069  LA72316  California  23405.98798              Bachelor
# 12070  PK87824  California  3096.511217               College
# 12071  TD14365  California  8163.890428              Bachelor
# 12072  UP19263  California  7524.442436               College
# 12073  Y167826  California  2611.836866               College
#
#       Customer lifetime value   Income  Monthly premiun auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# ...

# %%
#practica borrar duplicados #Check for duplicate rows in the data and remove if any
df1 = df1.drop_duplicates()
df1
# Out:
#       Customer       State       Gender             Education  \
# 0      RB50392  Washington          NaN                Master
# 1      QZ44356     Arizona            F              Bachelor
# 2      AI49188      Nevada            F              Bachelor
# 3      WW63253  California            M              Bachelor
# 4      GA49547  Washington            M  High School or Below
# ...        ...         ...          ...                   ...
# 12069  LA72316  California  23405.98798              Bachelor
# 12070  PK87824  California  3096.511217               College
# 12071  TD14365  California  8163.890428              Bachelor
# 12072  UP19263  California  7524.442436               College
# 12073  Y167826  California  2611.836866               College
#
#       Customer lifetime value   Income  Monthly premiun auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# ...

# %%
df1 = df1.reset_index(drop=True)
df1
# Out:
#      Customer       State       Gender             Education  \
# 0     RB50392  Washington          NaN                Master
# 1     QZ44356     Arizona            F              Bachelor
# 2     AI49188      Nevada            F              Bachelor
# 3     WW63253  California            M              Bachelor
# 4     GA49547  Washington            M  High School or Below
# ...       ...         ...          ...                   ...
# 9133  LA72316  California  23405.98798              Bachelor
# 9134  PK87824  California  3096.511217               College
# 9135  TD14365  California  8163.890428              Bachelor
# 9136  UP19263  California  7524.442436               College
# 9137  Y167826  California  2611.836866               College
#
#      Customer lifetime value   Income  Monthly premiun auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# ...

# %%
#Which columns are numerical? Income, Monthly Premiun auto, total claim amount

df1.dtypes
# Out:
# Customer                      object
# State                         object
# Gender                        object
# Education                     object
# Customer lifetime value       object
# Income                       float64
# Monthly premiun auto         float64
# Number of open complaints     object
# Policy type                   object
# Vehicle class                 object
# Total claim amount            object
# dtype: object

# %%
#Which columns are categorical?
#Customer, state, gender, education, , number of open complaints, policy type, vehicle_class

# %%
#Understand the meaning of all columns
customer: number to identify each customer
st: state 
gender: gender of customer
education: level of education
customer lifetime value: measure of the total income a business can expect to bring in from a typical customer for as long as that person or account remains a client (source)
income: income of client
monthly_premium_auto: ampunt of monthly payment the customer makes
number_of_open_complaints: complaints currently open
policy_type: type of policy
vehicle_class: type of vehicle
total_claim_amount: value of a claim
# Out:
#   File "C:\Users\danie\AppData\Local\Temp\ipykernel_23188\2095123015.py", line 2
#     customer: number to identify each customer
#                      ^
# SyntaxError: invalid syntax

# %%
#Delete the column education and the number of open complaints from the dataframe.
df1 = df1.drop(['Education','Number of open complaints'],axis=1)
df1
# Out:
#      Customer       State       Gender Customer lifetime value   Income  \
# 0     RB50392  Washington          NaN                     NaN      0.0
# 1     QZ44356     Arizona            F              697953.59%      0.0
# 2     AI49188      Nevada            F             1288743.17%  48767.0
# 3     WW63253  California            M              764586.18%      0.0
# 4     GA49547  Washington            M              536307.65%  36357.0
# ...       ...         ...          ...                     ...      ...
# 9133  LA72316  California  23405.98798                       M  71941.0
# 9134  PK87824  California  3096.511217                       F  21604.0
# 9135  TD14365  California  8163.890428                       M      0.0
# 9136  UP19263  California  7524.442436                       M  21941.0
# 9137  Y167826  California  2611.836866                       M      0.0
#
#       Monthly premiun auto     Policy type  Vehicle class Total claim amount
# ...

# %%
#Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
df1['Customer lifetime value']=df1['Customer lifetime value'].replace('%','', regex=True)*100 #.make.str.strip()
df1
# Out:
#      Customer       State       Gender  \
# 0     RB50392  Washington          NaN
# 1     QZ44356     Arizona            F
# 2     AI49188      Nevada            F
# 3     WW63253  California            M
# 4     GA49547  Washington            M
# ...       ...         ...          ...
# 9133  LA72316  California  23405.98798
# 9134  PK87824  California  3096.511217
# 9135  TD14365  California  8163.890428
# 9136  UP19263  California  7524.442436
# 9137  Y167826  California  2611.836866
#
#                                 Customer lifetime value   Income  \
# 0                                                   NaN      0.0
# 1     697953.59697953.59697953.59697953.59697953.596...      0.0
# 2     1288743.171288743.171288743.171288743.17128874...  48767.0
# 3     764586.18764586.18764586.18764586.18764586.187...      0.0
# 4     536307.65536307.65536307.65536307.65536307.655...  36357.0
# ...                                                 ...      ...
# ...

# %%
df1['Customer lifetime value'].dtype
# Out:
# dtype('O')

# %%
df1['Customer lifetime value'] = pd.to_numeric(df1['Customer lifetime value'])
df1['Customer lifetime value'].dtype
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
df1.duplicated().sum() #comporbar no hay duplicados
# Out:
# 0

# %%
#Filter out the data for customers who have an income of 0 or less.
df1[(df1['Income']<=0)]
# Out:
#      Customer       State Gender  \
# 0     RB50392  Washington    NaN
# 1     QZ44356     Arizona      F
# 3     WW63253  California      M
# 7     CF85061     Arizona      M
# 10    SX51350  California      M
# ...       ...         ...    ...
# 9127  WZ45103  California      F
# 9129  RX91025  California      M
# 9130  AC13887  California      M
# 9135  TD14365  California      M
# 9137  Y167826  California      M
#
#                                 Customer lifetime value  Income  \
# 0                                                   NaN     0.0
# 1     697953.59697953.59697953.59697953.59697953.596...     0.0
# 3     764586.18764586.18764586.18764586.18764586.187...     0.0
# 7     721610.03721610.03721610.03721610.03721610.037...     0.0
# 10    473899.20473899.20473899.20473899.20473899.204...     0.0
# ...                                                 ...     ...
# 9127                                        567805.0167     0.0
# ...
